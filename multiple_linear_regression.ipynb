# %%
import pandas as pd

df=pd.read_csv("datasets/ad.csv")
df.head()
# Out:
#    index     TV  radio  newspaper  sales
# 0      1  230.1   37.8       69.2   22.1
# 1      2   44.5   39.3       45.1   10.4
# 2      3   17.2   45.9       69.3    9.3
# 3      4  151.5   41.3       58.5   18.5
# 4      5  180.8   10.8       58.4   12.9

# %%
df.drop(['index'],inplace=True,axis=1)
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
X=df.drop(['sales'],axis=1)
y=df['sales']
print(X[:5])
print(y[:5])
# Out:
#       TV  radio  newspaper
# 0  230.1   37.8       69.2
# 1   44.5   39.3       45.1
# 2   17.2   45.9       69.3
# 3  151.5   41.3       58.5
# 4  180.8   10.8       58.4
# 0    22.1
# 1    10.4
# 2     9.3
# 3    18.5
# 4    12.9
# Name: sales, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,y,random_state=1)

print(x_train.shape," ",x_test.shape," ",y_train.shape," ",y_test.shape)
# Out:
# (150, 3)   (50, 3)   (150,)   (50,)

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()

reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print("slope=  ",reg.coef_)
print("intercept=  ",reg.intercept_)

print("y = ",reg.coef_,"x + ",reg.intercept_)
# Out:
# slope=   [0.04656457 0.17915812 0.00345046]
# intercept=   2.8769666223179335
# y =  [0.04656457 0.17915812 0.00345046] x +  2.8769666223179335

# %%
y_pred=reg.predict(x_test)
print(y_pred[:5])
print(y_test[:5])
# Out:
# [21.70910292 16.41055243  7.60955058 17.80769552 18.6146359 ]
# 58     23.8
# 40     16.6
# 34      9.5
# 102    14.8
# 184    17.6
# Name: sales, dtype: float64

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
import numpy as np

print("mean squared error is : ",mean_squared_error(y_test,y_pred))
print("mean absolute error is : ",mean_absolute_error(y_test,y_pred))
print("root mean squared error is : ",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# mean squared error is :  1.9730456202283384
# mean absolute error is :  1.0668917082595206
# root mean squared error is :  1.4046514230328955

# %%
reg.score(X,y)
# Out:
# 0.8963161233045729

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.pairplot(df, x_vars=['TV','radio','newspaper'], y_vars='sales', height=7, aspect=0.7, kind='reg')
